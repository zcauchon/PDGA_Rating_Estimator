# %%
from bs4 import BeautifulSoup
from requests import get
import pandas as pd
import re

# %%
url = "https://www.pdga.com/tour/event/86678"
page = get(url)
event_id = url.split("/")[-1]
soup = BeautifulSoup(page.content, "html.parser")

# %%
# first lets get tourny level info
records = []
event_name = soup.find('h1', attrs={'id':"page-title"}).text.replace('/','_')
event_info = soup.find_all("div", attrs={"class":"pane-tournament-event-info"})[0]
event_date = event_info.find('li', attrs={'class':"tournament-date"}).text.split(':')[1].strip()
event_location = event_info.find('li', attrs={'class':"tournament-location"}).text.split(":")[1].strip()
event_city, event_state, event_country = event_location.split(",")
event_director = event_info.find('li', attrs={'class': lambda L: L and L.endswith("-director")}).text.split(":")[1].strip()
event_type = event_info.find("h4").text
event_view = soup.find_all("div", attrs={"class":"pane-tournament-event-view"})
if event_view is not None:
    event_status = event_view[0].find("td", attrs={"class":"status"}).text
    if "Event complete" not in event_status:
        # event not finalized, dont gather data
        print('Event still pending', event_id)
    event_player_count = event_view[0].find("td", attrs={"class":"players"}).text
    try:
        event_purse = event_view.find("td", attrs={"class":"purse"}).text
    except AttributeError:
        event_purse = ""
else:
    event_player_count = ""
    event_purse = ""

#find each of the divisions in the event
divisions = soup.find_all('details')
for division in divisions:
    
    # each division can play at a different location/layout
    div_id = division.find("h3")["id"]
    rounds = division.find_all("th", attrs={"class":"round"})
    for round in rounds:
        # each round can be played at a different location/layout
        round_id = round.text.strip("Rd")
        round_info = division.find("div", attrs={"id":f"layout-details-{event_id}-{div_id}-round-{round_id}"}).text
        round_course = round_info.split(";")[0].split("-")[0].strip()
        round_layout = round_info.split(";")[0].split("-")[1].strip()
        round_holes = round_info.split(";")[1].split()[0].strip()
        round_par = round_info.split(";")[2].split()[1].strip()
        round_dist = round_info.split(";")[3].strip()
        # get each players score for this round
        players = division.find_all("tr")
        for player in players:
            if "th" in player.contents[0].name:
                continue
            try:
                player_points = player.find("td", attrs={"class":"points"}).text
            except AttributeError:
                player_points = ""
            player_pdga = player.find("td", attrs={"class":"pdga-number"}).text
            try:
                player_rating = player.find("td", attrs={"class":"player-rating"}).text
            except AttributeError:
                player_rating = ""
            player_round_score = player.find_all("td", attrs={"class":"round"})[int(round_id)-1].text
            player_round_rating = player.find_all("td", attrs={"class":"round-rating"})[int(round_id)-1].text
            # add all the info to the record list
            records.append([
                event_name,
                event_date,
                event_city,
                event_state,
                event_country,
                event_director,
                event_type,
                event_player_count,
                event_purse,
                div_id,
                round_id,
                round_course,
                round_layout,
                round_holes,
                round_par,
                round_dist,
                player_pdga,
                player_points,
                player_rating,
                player_round_score,
                player_round_rating
            ])

df = pd.DataFrame(columns=[
    "event_name",
    "event_date",
    "event_city",
    "event_state",
    "event_country",
    "event_director",
    "event_type",
    "event_player_count",
    "event_purse",
    "event_division",
    "round_number",
    "round_course",
    "round_layout",
    "layout_holes",
    "layout_par",
    "layout_distance",
    "player_pdga",
    "player_earned_points",
    "player_rating",
    "player_round_score",
    "player_round_rating"
], data=records)
df
# Out:
#                                event_name   event_date   event_city  \
# 0   2025 Kickoff presented by Latitude 64  02-Jan-2025  Gainesville
# 1   2025 Kickoff presented by Latitude 64  02-Jan-2025  Gainesville
# 2   2025 Kickoff presented by Latitude 64  02-Jan-2025  Gainesville
# 3   2025 Kickoff presented by Latitude 64  02-Jan-2025  Gainesville
# 4   2025 Kickoff presented by Latitude 64  02-Jan-2025  Gainesville
# 5   2025 Kickoff presented by Latitude 64  02-Jan-2025  Gainesville
# 6   2025 Kickoff presented by Latitude 64  02-Jan-2025  Gainesville
# 7   2025 Kickoff presented by Latitude 64  02-Jan-2025  Gainesville
# 8   2025 Kickoff presented by Latitude 64  02-Jan-2025  Gainesville
#
Easy Pin Locations Short Pads           18         54       4,081 ft.
# 17  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 18  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 19  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 20  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 21  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 22  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 23  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 24  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 25  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 26  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 27  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 28  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 29  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 30  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 31  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 32  Easy Pin Locations Short Pads           18         54       4,081 ft.
# 33  Easy Pin Locations Short Pads           18         54       4,081 ft.
#
#    player_pdga player_earned_points player_rating player_round_score  \
# 0       234248                15.00           969                 48
# 1       149862                10.00           957                 48
# 2       113591                 5.00           975                 50
# 3         4622                15.00           959                 44
# 4         7489                12.00           907                 49
# 5         7488                 9.00           908                 50
# 6       294779                 6.00           898                 59
# 7       296454                 3.00           838                 61
# 8       248403                20.00           939                 52
# 9        93575                15.00           905                 54
# 10      198359                15.00           877                 54
# 11      298624                 5.00                               57
# 12       11882                16.00           909                 52
# 13      278420                12.00           884                 57
# 14      114555                 8.00           856                 59
# 15      116397                 4.00           865                 60
# 16      244752                 2.00           798                 58
# 17      161838                 4.00           903                 50
# 18      297100                 2.00                               52
# 19      297871                 3.00                               55
# 20      298162                 1.50                               57
# 21      281369                26.00           839                 48
# 22      243306                24.00           809                 52
# 23      295738                24.00           820                 52
# 24                            24.00                               52
# 25      154505                18.00           818                 53
# 26      154506                18.00           803                 53
# 27      151938                14.00           785                 54
# 28                            14.00                               54
# 29      299032                10.00                               55
# 30                             8.00                               57
# 31      293615                 6.00           722                 61
# 32                             4.00                               62
# 33      297983                 2.00                               63
#
#    player_round_rating
# 0                  969
# 1                  969
# 2                  945
# 3                 1019
# 4                  957
# 5                  945
# 6                  833
# 7                  808
# 8                  920
# 9                  895
# 10                 895
# 11                 858
# 12                 920
# 13                 858
# 14                 833
# 15                 821
# 16                 769
# 17                 883
# 18                 855
# 19                 812
# 20                 784
# 21                 912
# 22                 855
# 23                 855
# 24                 855
# 25                 841
# 26                 841
# 27                 826
# 28                 826
# 29                 812
# 30                 784
# 31                 727
# 32                 712
# 33                 698
#
# [34 rows x 21 columns]

# %%
event_info.find('li', attrs={'class': lambda L: L and L.endswith("-director")}).text.split(":")[1].strip()
# Out:
# 'Derek Warner'

# %%
#find each of the division results
divisions = soup.find_all('details')
for division in divisions:
    # each division can play at a different location/layout
    div_id = division.find("h3")["id"]
    rounds = division.find_all("th", attrs={"class":"round"})
    for round in rounds:
        # each round can be played at a different location/layout
        round_id = round.text.strip("Rd")
        round_info = division.find("div", attrs={"id":f"layout-details-{event_id}-{div_id}-round-{round_id}"}).text
        round_course = round_info.split(";")[0].split("-")[0].strip()
        round_layout = round_info.split(";")[0].split("-")[1].strip()
        round_holes = round_info.split(";")[1].split()[0].strip()
        round_par = round_info.split(";")[2].split()[1].strip()
        round_dist = round_info.split(";")[3].strip()
        # get each players score for this round
        players = division.find_all("tr")
        for player in players:
            if "th" in player.contents[0].name:
                continue
            player_points = player.find("td", attrs={"class":"points"}).text
            player_pdga = player.find("td", attrs={"class":"pdga-number"}).text
            player_rating = player.find("td", attrs={"class":"player-rating"}).text
            player_round_score = player.find_all("td", attrs={"class":"round"})[int(round_id)-1].text
            player_round_rating = player.find_all("td", attrs={"class":"round-rating"})[int(round_id)-1].text
            records.append([
                event_name,
                event_date,
                event_city,
                event_state,
                event_country,
                event_director,
                event_type,
                event_player_count,
                event_purse,
                div_id,
                round_id,
                round_course,
                round_layout,
                round_holes,
                round_par,
                round_dist,
                player_pdga,
                player_points,
                player_rating,
                player_round_score,
                player_round_rating
            ])

# %%
df = pd.DataFrame(columns=[
    "event_name",
    "event_date",
    "event_city",
    "event_state",
    "event_country",
    "event_director",
    "event_type",
    "event_player_count",
    "event_purse",
    "event_division",
    "round_number",
    "round_course",
    "round_layout",
    "layout_holes",
    "layout_par",
    "layout_distance",
    "player_pdga",
    "player_earned_points",
    "player_rating",
    "player_round_score",
    "player_round_rating"
], data=records)
df
# Out:
#             event_name   event_date   event_city    event_state  \
# 0   Hickory Run Upshot  08-Feb-2025  White Haven   Pennsylvania
# 1   Hickory Run Upshot  08-Feb-2025  White Haven   Pennsylvania
# 2   Hickory Run Upshot  08-Feb-2025  White Haven   Pennsylvania
# 3   Hickory Run Upshot  08-Feb-2025  White Haven   Pennsylvania
# 4   Hickory Run Upshot  08-Feb-2025  White Haven   Pennsylvania
# ..                 ...          ...          ...            ...
# 77  Hickory Run Upshot  08-Feb-2025  White Haven   Pennsylvania
# 78  Hickory Run Upshot  08-Feb-2025  White Haven   Pennsylvania
# 79  Hickory Run Upshot  08-Feb-2025  White Haven   Pennsylvania
# 80  Hickory Run Upshot  08-Feb-2025  White Haven   Pennsylvania
# 81  Hickory Run Upshot  08-Feb-2025  White Haven   Pennsylvania
#
#      event_country   event_director       event_type event_player_count  \
# 0    United States  Brian Bochantin  Pro/Am   C-Tier                 41
# 1    United States  Brian Bochantin  Pro/Am   C-Tier                 41
# 2    United States  Brian Bochantin  Pro/Am   C-Tier                 41
# 3    United States  Brian Bochantin  Pro/Am   C-Tier                 41
# 4    United States  Brian Bochantin  Pro/Am   C-Tier                 41
# ..             ...              ...              ...                ...
# 77   United States  Brian Bochantin  Pro/Am   C-Tier                 41
# 78   United States  Brian Bochantin  Pro/Am   C-Tier                 41
# 79   United States  Brian Bochantin  Pro/Am   C-Tier                 41
# 80   United States  Brian Bochantin  Pro/Am   C-Tier                 41
# 81   United States  Brian Bochantin  Pro/Am   C-Tier                 41
#
#    event_purse event_division  ...            round_course  \
# 0         $112            MPO  ...  Hickory Run State Park
# 1         $112            MPO  ...  Hickory Run State Park
# 2         $112            MPO  ...  Hickory Run State Park
# 3         $112            MPO  ...  Hickory Run State Park
# 4         $112            MPO  ...  Hickory Run State Park
# ..         ...            ...  ...                     ...
# 77        $112            MA4  ...  Hickory Run State Park
# 78        $112            MA4  ...  Hickory Run State Park
# 79        $112            MA4  ...  Hickory Run State Park
# 80        $112            MA4  ...  Hickory Run State Park
# 81        $112            MA4  ...  Hickory Run State Park
#
#            round_layout layout_holes layout_par layout_distance player_pdga  \
# 0    BS Upshot Icy Long           18         54       4,835 ft.       99158
# 1    BS Upshot Icy Long           18         54       4,835 ft.       26126
# 2    BS Upshot Icy Long           18         54       4,835 ft.      197899
# 3    BS Upshot Icy Long           18         54       4,835 ft.      190907
# 4    BS Upshot Icy Long           18         54       4,835 ft.      201333
# ..                  ...          ...        ...             ...         ...
# 77  BS Upshot Icy Short           18         56       4,578 ft.      295265
# 78  BS Upshot Icy Short           18         56       4,578 ft.      293219
# 79  BS Upshot Icy Short           18         56       4,578 ft.      295676
# 80  BS Upshot Icy Short           18         56       4,578 ft.      207573
# 81  BS Upshot Icy Short           18         56       4,578 ft.      234733
#
#    player_earned_points player_rating player_round_score player_round_rating
# 0                 30.00           983                 48                1010
# 1                 25.00           981                 54                 945
# 2                 20.00           917                 52                 967
# 3                 15.00           932                 53                 956
# 4                 10.00           922                 57                 913
# ..                  ...           ...                ...                 ...
# 77                10.00           824                 61                 843
# 78                 8.00           796                 68                 762
# 79                 6.00           721                 67                 773
# 80                 0.00           783                999
# 81                 0.00           746                999
#
# [82 rows x 21 columns]

# %%
for course, course_df in df.groupby("round_course"):
    print(course)
# Out:
# Covered Bridge Park
